# %% [markdown]
# # Notebooks for loading data and dividing into training and testing datasets

# %%
import cv2
from glob import glob

# %%
#Paths to images
covid_path = "/home/Hachathon_Team_7/Challenge/datasets/Covid_Sars"
noncovid_path = "/home/Hachathon_Team_7/Challenge/datasets/Non_Covid_Sars"

# %%
# Use glob to grab images from path .jpg or jpeg
covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
#Store images
noncovid_images = []
noncovid_labels = []

for i in range(len(noncovid_files)):
    image  = cv2.imread(noncovid_files[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224,224))
    noncovid_images.append(image)
    noncovid_labels.append('CT_NonCOVID')

# %%
len(noncovid_images)
# Out:
# 1229

# %%
#Store Images
covid_images = []
covid_labels = []

for i in range(len(covid_files)):
    image  = cv2.imread(covid_files[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224,224))
    covid_images.append(image)
    covid_labels.append('CT_COVID')

# %%
len(covid_images)
# Out:
# 1252

# %%
#Example of an image from our data
import matplotlib.pyplot as plt
plt.imshow(covid_images[10])

# %%
from sklearn.model_selection import train_test_split
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# %%
len(covid_x_train)
# Out:
# 1001

# %%
#Example of a training image
plt.imshow(covid_x_train[1])

# %%
#Path
cov_path = "/home/Hachathon_Team_7/Challenge/datasets/Covid"
noncov_path = "/home/Hachathon_Team_7/Challenge/datasets/Non_Covid"

# %%
# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
noncov_files = glob(noncov_path + '/*')

# %%
#Store images
cov_images = []
cov_labels = []

for i in range(len(cov_files)):
    image  = cv2.imread(cov_files[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224,224))
    cov_images.append(image)
    cov_labels.append('CT_COVID')

# %%
len(cov_images)
# Out:
# 346

# %%
#Store images
noncov_images = []
noncov_labels = []

for i in range(len(noncov_files)):
    image  = cv2.imread(noncov_files[i])
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (224,224))
    noncov_images.append(image)
    noncov_labels.append('CT_NonCOVID')

# %%
len(noncov_images)
# Out:
# 335

# %%
from sklearn.model_selection import train_test_split
# Split into training and testing sets for both types of images
cov_x_train, cov_x_test, cov_y_train, cov_y_test = train_test_split(
    cov_images, cov_labels, test_size=0.2)
noncov_x_train, noncov_x_test, noncov_y_train, noncov_y_test = train_test_split(
    noncov_images, noncov_labels, test_size=0.2)

# %%
len(cov_x_train)
# Out:
# 276

# %% [markdown]
# # Save training and testing images into appropriate folder

# %%
for n in range(0, len(cov_x_train)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/train/Covid/image_{n}.png',image)

# %%
for n in range(0, len(noncov_x_train)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/train/Non_Covid/image_{n}.png',image)

# %%
for n in range(0, len(cov_x_test)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/test/Covid/image_{n}.png',image)

# %%
for n in range(0, len(noncov_x_test)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/test/Non_Covid/image_{n}.png',image)

# %%
for n in range(0, len(covid_x_train)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/train/Covid/sars_{n}.png',image)

# %%
for n in range(0, len(covid_x_train)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/train/Covid/sars_{n}.png',image)

# %%
for n in range(0, len(covid_x_test)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/test/Covid/sars_{n}.png',image)

# %%
for n in range(0, len(noncovid_x_train)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/train/Non_Covid/sars_{n}.png',image)

# %%
for n in range(0, len(noncovid_x_test)):
    # other things you need to do snipped
    cv2.imwrite(f'/home/Hachathon_Team_7/Challenge/datasets/test/Non_Covid/sars_{n}.png',image)
